# %%
from bs4 import BeautifulSoup
import requests as rq
import pandas as pd

# %%
url = 'https://eletronicos.mercadolivre.com.br/televisores/4k/'
page = BeautifulSoup(rq.get(url).text, 'html.parser')

# %%
page
# Out:
# <!DOCTYPE html>
#
# <html lang="pt-BR">
# ...

# %%
page.find('h1', class_='ui-search-breadcrumb__title').text
# Out:
# 'Televisores 4K'
